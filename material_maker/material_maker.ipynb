# %% [markdown]
# # Material Maker
#
# Building protocol buffer cross-section files requires the protocol buffer
# libraries generated by the [cross_section_protobuf](https://github.com/jsrehak/cross_section_protobuf)
#  package. Update this to the location of that repo on your local machine:

# %%
cross_section_protobuf_repo_location = "../../cross_section_protobuf"

# %% [markdown]
# And run the protocol buffer compiler and import the generated library:
